# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
data = pd.read_csv("D:\\techstack\\ab sir\\Big Mart Sales\\Big Mart Sales.csv")
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.plot('Item_MRP','Item_Outlet_Sales')

# %%
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')
plt.scatter(data.Item_MRP,data.Item_Outlet_Sales,color='red')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %%
data = data.dropna()
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# 13             FDS46       17.600          Regular         0.047257
# 14             FDF32       16.350          Low Fat         0.068024
# 15             FDP49        9.000          Regular         0.069089
# 16             NCB42       11.800          Low Fat         0.008596
# ...

# %%
del data['Item_Identifier']

# %%
data.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility     Item_Type  Item_MRP  \
# 0        9.300          Low Fat         0.016047         Dairy  249.8092
# 1        5.920          Regular         0.019278   Soft Drinks   48.2692
# 2       17.500          Low Fat         0.016760          Meat  141.6180
# 4        8.930          Low Fat         0.000000     Household   53.8614
# 5       10.395          Regular         0.000000  Baking Goods   51.4008
#
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
# 1            OUT018                       2009      Medium
# 2            OUT049                       1999      Medium
# 4            OUT013                       1987        High
# 5            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# ...

# %%
data.shape
# Out:
# (4650, 11)

# %%
data
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 4           8.930          Low Fat         0.000000              Household
# 5          10.395          Regular         0.000000           Baking Goods
# 6          13.650          Regular         0.012741            Snack Foods
# 10         11.800          Low Fat         0.000000  Fruits and Vegetables
# 11         18.500          Regular         0.045464                  Dairy
# 12         15.100          Regular         0.100014  Fruits and Vegetables
# 13         17.600          Regular         0.047257            Snack Foods
# 14         16.350          Low Fat         0.068024  Fruits and Vegetables
# ...

# %%
X=data.iloc[:,4]
X
# Out:
# 0       249.8092
# 1        48.2692
# 2       141.6180
# 4        53.8614
# 5        51.4008
# 6        57.6588
# 10       45.5402
# 11      144.1102
# 12      145.4786
# 13      119.6782
# 14      196.4426
# 15       56.3614
# 16      115.3492
# 17       54.3614
# 19      230.5352
# 20      250.8724
# 22      196.5084
# 24      165.0210
# 26       42.3112
# 27       39.1164
# 31       96.4436
# 32      256.6672
# 34      174.8738
# 35      146.7102
# 37      122.5388
# 40      230.6352
# 41      126.0020
# 42      192.9136
# 43      259.9278
# 44      126.5046
#           ...
# 8466     61.2536
# 8467    175.2370
# 8470    155.1314
# 8475     92.5436
# 8478    121.3098
# 8479     99.1042
# 8482    125.8678
# 8484    129.9652
# 8489     89.6856
# 8491    227.9352
# 8492    104.4964
# 8495    160.4920
# 8497    150.0050
# 8498    124.5730
# 8499    100.0042
# 8503    120.1756
# 8505    210.8244
# 8506    263.1910
# 8507    101.7990
# 8510    231.5984
# 8511    262.5910
# ...

# %%
X=data.iloc[:,4].values.reshape(-1,1)
X
# Out:
# array([[249.8092],
#        [ 48.2692],
#        [141.618 ],
#        ...,
#        [ 85.1224],
#        [103.1332],
#        [ 75.467 ]])

# %%
y=data.iloc[:,10]
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 4        994.7052
# 5        556.6088
# 6        343.5528
# 10      1516.0266
# 11      2187.1530
# 12      1589.2646
# 13      2145.2076
# 14      1977.4260
# 15      1547.3192
# 16      1621.8888
# 17       718.3982
# 19      2748.4224
# 20      3775.0860
# 22      1587.2672
# 24      4078.0250
# 26      1065.2800
# 27       308.9312
# 31      2741.7644
# 32      3068.0064
# 34      2085.2856
# 35      3791.0652
# 37      1609.9044
# 40      3435.5280
# 41      2150.5340
# 42      2527.3768
# 43      6768.5228
# 44       373.5138
#           ...
# 8466     673.7896
# 8467    3881.6140
# 8470    1551.3140
# 8475     378.1744
# 8478    4820.3920
# 8479    2579.3092
# 8482     763.0068
# 8484    2324.9736
# 8489    2109.2544
# 8491    4809.7392
# 8492    2419.5172
# 8495    4314.3840
# 8497    2247.0750
# 8498    1601.2490
# 8499    2976.1260
# 8503    3392.9168
# 8505    2117.2440
# 8506    3944.8650
# 8507     515.9950
# ...

# %%
y=data.iloc[:,10].values.reshape(-1,1)
y
# Out:
# array([[3735.138 ],
#        [ 443.4228],
#        [2097.27  ],
#        ...,
#        [1193.1136],
#        [1845.5976],
#        [ 765.67  ]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# # Linear Regression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pred = reg.predict(X_test)

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, pred))
# Out:
# Model R^2 Square value 0.2096453348252718

# %%
reg.score(y_test,pred)
# Out:
# -0.04718604322569875

# %% [markdown]
# # Polynimal Reg.

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg = PolynomialFeatures(degree = 2)
X_poly = poly_reg.fit_transform(X)
print('X',X)
print(X_poly)

lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# X [[249.8092]
#  [ 48.2692]
#  [141.618 ]
#  ...
#  [ 85.1224]
#  [103.1332]
#  [ 75.467 ]]
# [[1.00000000e+00 2.49809200e+02 6.24046364e+04]
#  [1.00000000e+00 4.82692000e+01 2.32991567e+03]
#  [1.00000000e+00 1.41618000e+02 2.00556579e+04]
#  ...
#  [1.00000000e+00 8.51224000e+01 7.24582298e+03]
#  [1.00000000e+00 1.03133200e+02 1.06364569e+04]
#  [1.00000000e+00 7.54670000e+01 5.69526809e+03]]
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.score(y_test,pred)
# Out:
# -0.04718604322569875

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, pred))
# Out:
# Model R^2 Square value 0.2096453348252718

# %% [markdown]
# # SVM

# %%
from sklearn import svm

# %%
reg = svm.SVR(kernel='linear',gamma=0.02)

# %%
reg.fit(X_train,y_train)
# Out:
# C:\Users\New\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
pred = reg.predict(X_test)

# %%
reg.score(y_test,pred)
# Out:
# -0.043822740858763254

# %%
print('Model R^2 Square value', metrics.r2_score(y_test, pred))
# Out:
# Model R^2 Square value -0.02396774686108727

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(reg.fit(X_train,y_train),X,y,cv=5)
# Out:
# C:\Users\New\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\New\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\New\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor(random_state=1)

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\New\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\New\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
pred=model.predict(X_test)

# %%
model.score(X_test,pred)
# Out:
# 1.0

# %%
print('Model R^2 Square value', metrics.r2_score(y_test,pred))
# Out:
# Model R^2 Square value 0.19033067637506373
